# %%
import polars as pl


from preprocess.evaluation import get_correct_answers, classification_accuracy, create_predictions
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import polars as pl
#       2
#       3
# ----> 4 from preprocess.evaluation import get_correct_answers, classification_accuracy, create_predictions
#
# File ~/Documents/open_source_projects/dp-categorical-classification/src/preprocess/evaluation.py:4
#       1 """Has methods to calculate"""
#       3 from frozendict import frozendict
# ----> 4 from preprocess.data_reader import DATASET_DIRS, SAMPLE_DATASETS_DIR
#       5 from preprocess.dp_calculations import calculate_values
#       6 import polars as pl
#
# File ~/Documents/open_source_projects/dp-categorical-classification/src/preprocess/data_reader.py:11
#       4 import os
#       6 SAMPLE_DATASETS_DIR = os.path.join(
#       7     os.path.dirname(os.path.dirname(__file__)), "sample-datasets"
#       8 )
#       9 DATASET_DIRS = [
# ...
