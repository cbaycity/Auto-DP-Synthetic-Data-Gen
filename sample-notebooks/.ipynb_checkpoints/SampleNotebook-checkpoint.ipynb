# %%
import polars as pl


from evaluation import get_correct_answers, classification_accuracy, create_predictions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 import polars as pl
#       2
#       3
# ----> 4 from evaluation import get_correct_answers, classification_accuracy, create_predictions
#
# ModuleNotFoundError: No module named 'evaluation'
